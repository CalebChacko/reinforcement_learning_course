# %% [markdown]
# The course content and data was found from this video:
# https://www.youtube.com/watch?v=Mut_u40Sqz4&list=PLhm50nnh4R_QNWQX45Z0u5_C2Yg1PueCu&index=1&t=814s

# %% [markdown]
# ## Setup

# %%
# reinforcement learning package
# documentation: https://stable-baselines3.readthedocs.io/en/master/
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (1.4.0)
# Requirement already satisfied: cloudpickle in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (1.6.0)
# Requirement already satisfied: numpy in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (1.22.2)
# Requirement already satisfied: pandas in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: torch>=1.8.1 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (1.10.2)
# Requirement already satisfied: matplotlib in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: gym<0.20,>=0.17 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (0.19.0)
# Requirement already satisfied: tensorboard>=2.2.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (2.8.0)
# Requirement already satisfied: opencv-python in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (4.5.5.62)
# Requirement already satisfied: psutil in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: pillow in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: atari-py==0.2.6 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from stable-baselines3[extra]) (0.2.6)
# Requirement already satisfied: six in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from atari-py==0.2.6->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.2)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.19.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.6)
# Requirement already satisfied: absl-py>=0.4 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (58.0.4)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.43.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->stable-baselines3[extra]) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.11)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: typing-extensions in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from torch>=1.8.1->stable-baselines3[extra]) (4.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (0.19.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from gym) (1.22.2)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\12049\anaconda3\envs\rl_env\lib\site-packages (from gym) (1.6.0)

# %%
import os
import gym
from stable_baselines3 import PPO # algorithm
from stable_baselines3.common.vec_env import DummyVecEnv # wrapper to boost training time
from stable_baselines3.common.evaluation import evaluate_policy # avg reward over episodes

# %% [markdown]
# ## Environment

# %% [markdown]
# open ai gym allows you to build simulated envs quickly
# Documentation: https://gym.openai.com/docs/

# %%
# OpenAi Spaces
# Box - Continuous values
# Discrete - set of items
# Tuple - tuple of other spaces (not supported with baseline)
# Dict - dictionary of spaces
# MultiBinary - one hot encoded binary values (i.e. [0, 1, 0, 0])
# MultiDiscrete - multiple discrete values

# %%
# 2 different spaces
# Observation (circumstance) and Action (actions you can take)

# %%
env_name = 'CartPole-v0'
env = gym.make(env_name)

# %%
env_name
# Out:
# 'CartPole-v0'

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset() # obersvations for our environment (circumstance)
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample() # random action (0 or 1)
        n_state, reward, done, info = env.step(action)
        score += reward
        
    print('Episode:{}, Score:{}'.format(episode, score))
    
env.close()
# Out:
# Episode:1, Score:38.0
# Episode:2, Score:10.0
# Episode:3, Score:46.0
# Episode:4, Score:19.0
# Episode:5, Score:59.0

# %% [markdown]
# ### Understanding the Environment

# %% [markdown]
# Documentation: https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
env.action_space # 0 = left , 1 = right
# Out:
# Discrete(2)

# %%
env.action_space.sample
# Out:
# <bound method Discrete.sample of Discrete(2)>

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.observation_space.sample()
# Out:
# array([-3.4120877e+00,  5.4195881e+37,  1.9362877e-01, -2.9853823e+38],
#       dtype=float32)

# %% [markdown]
# ## Training RL Model

# %%
# We're focused on
# Model-Free RL -> Policy Optimization -> PPO, A2C
# Model-Free RL -> Q-Learning -> QR-DQN
# Model-Free only makes actions based on current information
# stable-baseline only works with Model-Free

# %%
# Setup up Directories 
# Training -> Logs
# Training -> Saved Models
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda:env]) # wrapping env
model=PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# multi layerd perceptron policy is a Vanilla Neural Network
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 2110 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1451       |
# |    iterations           | 2          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00615729 |
# |    clip_fraction        | 0.0719     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.687     |
# |    explained_variance   | 0.000759   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.18       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 66         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1301        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010053566 |
# |    clip_fraction        | 0.0635      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.0841      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.63        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 30.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1241       |
# |    iterations           | 4          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00870702 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.639     |
# |    explained_variance   | 0.265      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.9       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0229    |
# |    value_loss           | 50.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009646371 |
# |    clip_fraction        | 0.0919      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 59.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1192        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011081742 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 61.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1172         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0068731788 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00622     |
# |    value_loss           | 52.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1150         |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0038720798 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 52.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1136         |
# |    iterations           | 9            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0086626755 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.0924       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.52         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00521     |
# |    value_loss           | 37.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1135         |
# |    iterations           | 10           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0053681307 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.65         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00626     |
# |    value_loss           | 23           |
# ------------------------------------------

# %% [markdown]
# ## Save and Reload Model

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path, env=env)

# %% [markdown]
# ## Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# render lets you see it realtime
# Out:
# C:\Users\12049\Anaconda3\envs\rl_env\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
# 200 = avg reward (200 is the max)
# 0 is the standard deviation
env.close()

# %% [markdown]
# ## Test Model

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset() # obersvations for our environment (circumstance)
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(obs) # NOW USING MODEL
        obs, reward, done, info = env.step(action)
        score += reward
        
    print('Episode:{}, Score:{}'.format(episode, score))
    
env.close()
# Out:
# Episode:1, Score:[200.]
# Episode:2, Score:[182.]
# Episode:3, Score:[200.]
# Episode:4, Score:[200.]
# Episode:5, Score:[200.]

# %%
obs = env.reset()

# %%
action, _ = model.predict(obs) # model action and next state

# %%
env.action_space.sample()

# %%
env.step(action)
# Out:
# (array([[-0.02628942,  0.20397522, -0.0127049 , -0.32968247]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{}])

# %% [markdown]
# ## Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_1')

# %%
# kick it off in the desired PPO folder
# http://localhost:6006/
# !tensorboard --logdir={training_log_path}
# Out:
# ^C

# %% [markdown]
# ## Adding a callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
# stop once we reach the 200 reward threshold
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env,
                            callback_on_new_best=stop_callback,
                            eval_freq=10000, 
                            best_model_save_path=save_path,
                            verbose=1)

# %%
# new PPO model
model=PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 2270 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1487        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008871145 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.0124      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.18        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 54          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1342         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0100040445 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.0474       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0168      |
# |    value_loss           | 37.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012212217 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 58.2        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.007060991 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 70.4        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# ## Changing Policies

# %%
# 2 neural networks
# first is for the actor 128 nodes and 4 layers
# second is for the ... 128 nodes and 4 layers
net_arch = [dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
# Specify new neural network policy
model=PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 1374 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016260192 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 0.00013     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.45        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 19.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 797        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01948875 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.635     |
# |    explained_variance   | 0.462      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.83       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0347    |
# |    value_loss           | 25.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 749        |
# |    iterations           | 4          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01084701 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.592     |
# |    explained_variance   | 0.523      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.7       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0268    |
# |    value_loss           | 41.5       |
# ----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.013005445 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.8         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 29.9        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 705   |
# |    iterations      | 5     |
# |    time_elapsed    | 14    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008743754 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.1         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00935    |
# |    value_loss           | 25          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 690         |
# |    iterations           | 7           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007943109 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00777    |
# |    value_loss           | 11.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 686         |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006033535 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.711       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00788    |
# |    value_loss           | 5.49        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 685          |
# |    iterations           | 9            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0066603925 |
# |    clip_fraction        | 0.092        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.507       |
# |    explained_variance   | 0.718        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.11         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00622     |
# |    value_loss           | 11.7         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.015532102 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.459      |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.351       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00512    |
# |    value_loss           | 2.66        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 671   |
# |    iterations      | 10    |
# |    time_elapsed    | 30    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# ## Using an Alternate Algorithm

# %%
# try using DQN
from stable_baselines3 import DQN

# %%
model=DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5120     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 87       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 6779     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 183      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7567     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 265      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 7868     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 354      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 7450     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 447      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 7338     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 543      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7262     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 632      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7370     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 715      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 7518     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 827      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7621     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 884      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 7632     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 954      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 7800     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 7786     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.426    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 7894     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.398    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 7876     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1268     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8046     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8226     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8223     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.19     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8277     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.15     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8364     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1790     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8360     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0809   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 8376     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 8406     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2009     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 8587     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 8627     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2278     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 8687     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 8769     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 8819     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 8826     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              |